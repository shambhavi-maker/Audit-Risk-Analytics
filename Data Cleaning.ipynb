# %%
import numpy as np
import pandas as pd


import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df0 = pd.read_csv('audit_risk.csv')
trial = pd.read_csv('trial.csv')

# %%
df0.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  \
# 0          3.89          23    4.18      0.6   2.508    2.50      0.2   0.500
# 1          3.89           6    0.00      0.2   0.000    4.83      0.2   0.966
# 2          3.89           6    0.51      0.2   0.102    0.23      0.2   0.046
# 3          3.89           6    0.00      0.2   0.000   10.80      0.6   6.480
# 4          3.89           6    0.00      0.2   0.000    0.08      0.2   0.016
#
#    TOTAL  numbers  ...  RiSk_E  History  Prob  Risk_F  Score  Inherent_Risk  \
# 0   6.68      5.0  ...     0.4        0   0.2     0.0    2.4          8.574
# 1   4.83      5.0  ...     0.4        0   0.2     0.0    2.0          2.554
# 2   0.74      5.0  ...     0.4        0   0.2     0.0    2.0          1.548
# 3  10.80      6.0  ...     0.4        0   0.2     0.0    4.4         17.530
# 4   0.08      5.0  ...     0.4        0   0.2     0.0    2.0          1.416
#
#    CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0           0.4             0.5      1.7148     1
# 1           0.4             0.5      0.5108     0
# 2           0.4             0.5      0.3096     0
# 3           0.4             0.5      3.5060     1
# 4           0.4             0.5      0.2832     0
#
# [5 rows x 27 columns]

# %%
trial.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  SCORE_A  PARA_B  SCORE_B  TOTAL  numbers  \
# 0          3.89          23    4.18        6    2.50        2   6.68      5.0
# 1          3.89           6    0.00        2    4.83        2   4.83      5.0
# 2          3.89           6    0.51        2    0.23        2   0.74      5.0
# 3          3.89           6    0.00        2   10.80        6  10.80      6.0
# 4          3.89           6    0.00        2    0.08        2   0.08      5.0
#
#    Marks  Money_Value  MONEY_Marks  District  Loss  LOSS_SCORE  History  \
# 0      2         3.38            2         2     0           2        0
# 1      2         0.94            2         2     0           2        0
# 2      2         0.00            2         2     0           2        0
# 3      6        11.75            6         2     0           2        0
# 4      2         0.00            2         2     0           2        0
#
#    History_score  Score  Risk
# 0              2    2.4     1
# 1              2    2.0     0
# 2              2    2.0     0
# 3              2    4.4     1
# 4              2    2.0     0

# %%
#Renaming columns
trial.columns = ['Sector_score','LOCATION_ID', 'PARA_A', 'Score_A', 'PARA_B',
       'Score_B',  'TOTAL', 'numbers', 'Marks',
       'Money_Value', 'MONEY_Marks', 'District',
       'Loss', 'LOSS_SCORE', 'History', 'History_score', 'Score', 'Risk_trial' ]

# %%
trial['Score_A'] = trial['Score_A']/10
trial['Score_B'] = trial['Score_B']/10

# %%
same_columns = np.intersect1d(df0.columns, trial.columns)
same_columns
# Out:
# array(['History', 'LOCATION_ID', 'Money_Value', 'PARA_A', 'PARA_B',
#        'Score', 'Score_A', 'Score_B', 'Sector_score', 'TOTAL', 'numbers'],
#       dtype=object)

# %%
df0.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B',
#        'Score_B', 'Risk_B', 'TOTAL', 'numbers', 'Score_B.1', 'Risk_C',
#        'Money_Value', 'Score_MV', 'Risk_D', 'District_Loss', 'PROB', 'RiSk_E',
#        'History', 'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK',
#        'Detection_Risk', 'Audit_Risk', 'Risk'],
#       dtype='object')

# %%
df1=df0.drop('Score_B.1',axis=1)
df1.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B',
#        'Score_B', 'Risk_B', 'TOTAL', 'numbers', 'Risk_C', 'Money_Value',
#        'Score_MV', 'Risk_D', 'District_Loss', 'PROB', 'RiSk_E', 'History',
#        'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK',
#        'Detection_Risk', 'Audit_Risk', 'Risk'],
#       dtype='object')

# %%
trial=trial.drop(['Risk_trial'], axis = 1)

# %%
# Merge two Dataframes  on common columns  using outer join
merged_df = pd.merge(df1, trial, how='outer', on = ['History', 'LOCATION_ID', 'Money_Value', 'PARA_A', 'PARA_B',
       'Score', 'Score_A', 'Score_B', 'Sector_score', 'TOTAL', 'numbers'])
merged_df.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B',
#        'Score_B', 'Risk_B', 'TOTAL', 'numbers', 'Risk_C', 'Money_Value',
#        'Score_MV', 'Risk_D', 'District_Loss', 'PROB', 'RiSk_E', 'History',
#        'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK',
#        'Detection_Risk', 'Audit_Risk', 'Risk', 'Marks', 'MONEY_Marks',
#        'District', 'Loss', 'LOSS_SCORE', 'History_score'],
#       dtype='object')

# %%
df=merged_df

# %%
df.isnull().sum()
# Out:
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Risk_C            0
# Money_Value       1
# Score_MV          0
# Risk_D            0
# District_Loss     0
# PROB              0
# RiSk_E            0
# History           0
# Prob              0
# Risk_F            0
# Score             0
# Inherent_Risk     0
# CONTROL_RISK      0
# Detection_Risk    0
# Audit_Risk        0
# Risk              0
# Marks             0
# MONEY_Marks       0
# District          0
# Loss              0
# LOSS_SCORE        0
# History_score     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sector_score    810 non-null    float64
#  1   LOCATION_ID     810 non-null    object
#  2   PARA_A          810 non-null    float64
#  3   Score_A         810 non-null    float64
#  4   Risk_A          810 non-null    float64
#  5   PARA_B          810 non-null    float64
#  6   Score_B         810 non-null    float64
#  7   Risk_B          810 non-null    float64
#  8   TOTAL           810 non-null    float64
#  9   numbers         810 non-null    float64
#  10  Risk_C          810 non-null    float64
#  11  Money_Value     809 non-null    float64
#  12  Score_MV        810 non-null    float64
#  13  Risk_D          810 non-null    float64
#  14  District_Loss   810 non-null    int64
#  15  PROB            810 non-null    float64
#  16  RiSk_E          810 non-null    float64
#  17  History         810 non-null    int64
#  18  Prob            810 non-null    float64
#  19  Risk_F          810 non-null    float64
#  20  Score           810 non-null    float64
#  21  Inherent_Risk   810 non-null    float64
#  22  CONTROL_RISK    810 non-null    float64
#  23  Detection_Risk  810 non-null    float64
#  24  Audit_Risk      810 non-null    float64
#  25  Risk            810 non-null    int64
#  26  Marks           810 non-null    int64
#  27  MONEY_Marks     810 non-null    int64
#  28  District        810 non-null    int64
#  29  Loss            810 non-null    int64
#  30  LOSS_SCORE      810 non-null    int64
#  31  History_score   810 non-null    int64
# dtypes: float64(22), int64(9), object(1)
# memory usage: 202.6+ KB

# %%
df.shape
# Out:
# (810, 32)

# %%
#Replacing the missing value by the median of the column
df['Money_Value'] = df['Money_Value'].fillna(df['Money_Value'].median())

# %%
# Identify and drop duplicate columns
df = df.loc[:,~df.columns.duplicated()]
df.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B',
#        'Score_B', 'Risk_B', 'TOTAL', 'numbers', 'Risk_C', 'Money_Value',
#        'Score_MV', 'Risk_D', 'District_Loss', 'PROB', 'RiSk_E', 'History',
#        'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK',
#        'Detection_Risk', 'Audit_Risk', 'Risk', 'Marks', 'MONEY_Marks',
#        'District', 'Loss', 'LOSS_SCORE', 'History_score'],
#       dtype='object')

# %%
#Unique values in LOCATION_ID column
df["LOCATION_ID"].unique()
# Out:
# array(['23', '6', '7', '8', '13', '37', '24', '3', '4', '14', '5', '20',
#        '19', '21', '22', '9', '11', '12', '29', '30', '38', '31', '2',
#        '32', '16', '33', '15', '36', '34', '18', '25', '39', '27', '35',
#        '40', '41', '42', '1', '28', 'LOHARU', 'NUH', 'SAFIDON', '43',
#        '44', '17'], dtype=object)

# %%
#Replacing the missing value by the median of the column
df['Money_Value'] = df['Money_Value'].fillna(df['Money_Value'].median())

# %%
df = df[(df.LOCATION_ID != 'LOHARU')]
df = df[(df.LOCATION_ID != 'NUH')]
df = df[(df.LOCATION_ID != 'SAFIDON')]
df = df.astype(float)
print("Updated number of rows in the dataset: ",len(df))
# Out:
# Updated number of rows in the dataset:  807

# %%
df = df.drop_duplicates(keep = 'first')
print("Updated number of rows in the dataset: ",len(df))
# Out:
# Updated number of rows in the dataset:  760

# %%
#Number of unique values in each columns
for i in range(0, len(df.columns)):
    print(df.columns[i], ":", df.iloc[:,i].nunique())
# Out:
# Sector_score : 13
# LOCATION_ID : 42
# PARA_A : 362
# Score_A : 3
# Risk_A : 362
# PARA_B : 358
# Score_B : 3
# Risk_B : 360
# TOTAL : 470
# numbers : 5
# Risk_C : 5
# Money_Value : 327
# Score_MV : 3
# Risk_D : 327
# District_Loss : 3
# PROB : 3
# RiSk_E : 5
# History : 7
# Prob : 3
# Risk_F : 7
# Score : 17
# Inherent_Risk : 583
# CONTROL_RISK : 11
# Detection_Risk : 1
# Audit_Risk : 600
# Risk : 2
# Marks : 3
# MONEY_Marks : 3
# District : 3
# Loss : 3
# LOSS_SCORE : 3
# History_score : 3

# %%
df.head()
# Out:
#    Sector_score  LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  \
# 0          3.89         23.0    4.18      0.6   2.508    2.50      0.2
# 1          3.89          6.0    0.00      0.2   0.000    4.83      0.2
# 2          3.89          6.0    0.51      0.2   0.102    0.23      0.2
# 3          3.89          6.0    0.00      0.2   0.000   10.80      0.6
# 4          3.89          6.0    0.00      0.2   0.000    0.08      0.2
#
#    Risk_B  TOTAL  numbers  ...  CONTROL_RISK  Detection_Risk  Audit_Risk  \
# 0   0.500   6.68      5.0  ...           0.4             0.5      1.7148
# 1   0.966   4.83      5.0  ...           0.4             0.5      0.5108
# 2   0.046   0.74      5.0  ...           0.4             0.5      0.3096
# 3   6.480  10.80      6.0  ...           0.4             0.5      3.5060
# 4   0.016   0.08      5.0  ...           0.4             0.5      0.2832
#
#    Risk  Marks  MONEY_Marks  District  Loss  LOSS_SCORE  History_score
# 0   1.0    2.0          2.0       2.0   0.0         2.0            2.0
# 1   0.0    2.0          2.0       2.0   0.0         2.0            2.0
# 2   0.0    2.0          2.0       2.0   0.0         2.0            2.0
# 3   1.0    6.0          6.0       2.0   0.0         2.0            2.0
# 4   0.0    2.0          2.0       2.0   0.0         2.0            2.0
#
# [5 rows x 32 columns]

# %%
df.to_csv('sample.csv')

# %%
dfg=pd.read_csv('sample.csv')
dfg.head()
# Out:
#    Unnamed: 0  Sector_score  LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  \
# 0           0          3.89         23.0    4.18      0.6   2.508    2.50
# 1           1          3.89          6.0    0.00      0.2   0.000    4.83
# 2           2          3.89          6.0    0.51      0.2   0.102    0.23
# 3           3          3.89          6.0    0.00      0.2   0.000   10.80
# 4           4          3.89          6.0    0.00      0.2   0.000    0.08
#
#    Score_B  Risk_B  TOTAL  ...  CONTROL_RISK  Detection_Risk  Audit_Risk  \
# 0      0.2   0.500   6.68  ...           0.4             0.5      1.7148
# 1      0.2   0.966   4.83  ...           0.4             0.5      0.5108
# 2      0.2   0.046   0.74  ...           0.4             0.5      0.3096
# 3      0.6   6.480  10.80  ...           0.4             0.5      3.5060
# 4      0.2   0.016   0.08  ...           0.4             0.5      0.2832
#
#    Risk  Marks  MONEY_Marks  District  Loss  LOSS_SCORE  History_score
# 0   1.0    2.0          2.0       2.0   0.0         2.0            2.0
# 1   0.0    2.0          2.0       2.0   0.0         2.0            2.0
# 2   0.0    2.0          2.0       2.0   0.0         2.0            2.0
# 3   1.0    6.0          6.0       2.0   0.0         2.0            2.0
# 4   0.0    2.0          2.0       2.0   0.0         2.0            2.0
#
# [5 rows x 33 columns]
